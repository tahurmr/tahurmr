# %% [markdown]
# <a href="https://colab.research.google.com/github/tahurmr/tahurmr/blob/main/py_Internship_prbm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#step1 : import library
import pandas as pd

# %%
#step 2: imprt data
salary =pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Salary%20Data.csv')

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
#step3: define target(y) and features(x)
y = salary['Salary'] #if asking coding then single bracket and if asking logic then it has to be depending value represented by double bracket
x = salary[['Experience Years']] #asking logic

# %%
salary.shape
# Out:
# (40, 2)

# %%
y.shape
# Out:
# (40,)

# %%
x.shape
# Out:
# (40, 1)

# %%
#step4 = train test split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y) #it will split the train : test = 75% : 25% by default

# %%
#if we want to split the train test ratio as per our reference/wish
#x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7) #train_size=0.7 means 70%... if 0.8 it means 80%...

# %%
x_train
# Out:
#     Experience Years
# 7                2.9
# 15               4.0
# 33               8.5
# 17               4.1
# 6                2.5
# 31               7.9
# 13               3.8
# 30               7.1
# 10               3.2
# 27               6.2
# 24               5.5
# 25               5.9
# 28               6.5
# 1                1.2
# 34               8.7
# 4                2.0
# 35               9.0
# 26               6.0
# 12               3.7
# 23               5.3
# 2                1.3
# 32               8.2
# 38              10.3
# 37               9.6
# 8                3.0
# 29               6.8
# 19               4.5
# 36               9.5

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((30, 1), (10, 1), (30,), (10,))
